# %%
cd C:\Users\ab42313\OneDrive\ABZ_PhD\Rosalind
# Out:
# C:\Users\ab42313\OneDrive\ABZ_PhD\Rosalind

# %% [markdown]
# ### Ordering Strings of Varying Length Lexicographically

# %% [markdown]
# Given: A permutation of at most 12 symbols defining an ordered alphabet A and a positive integer n (n≤4).
#
# Return: All strings of length at most n formed from A, ordered lexicographically. (Note: As in “Enumerating k-mers Lexicographically”, alphabet order is based on the order in which the symbols are given.)

# %%
import itertools
import operator
import os

file = open('files/lexv_example.txt','rU')
raw_file = file.read()
order = raw_file.split('\n')[0].split(' ')                
n = int(raw_file.split('\n')[1])

print 'Order: ', order
print 'n: ', n

all_comb = []

for i in range(1,n+1):
    for m in itertools.product(order,repeat= i):
        all_comb.append(m)

print all_comb
print len(all_comb)

provv = []

for m in order:
    for i in all_comb:    
        if len(i) == 1:
            print i
            if i[0] == m:
                provv.append(i)
        elif len(i) == 2:
            print i
        
            

                
print provv
# Out:
# Order:  ['D', 'N', 'A']
# n:  3
# [('D',), ('N',), ('A',), ('D', 'D'), ('D', 'N'), ('D', 'A'), ('N', 'D'), ('N', 'N'), ('N', 'A'), ('A', 'D'), ('A', 'N'), ('A', 'A'), ('D', 'D', 'D'), ('D', 'D', 'N'), ('D', 'D', 'A'), ('D', 'N', 'D'), ('D', 'N', 'N'), ('D', 'N', 'A'), ('D', 'A', 'D'), ('D', 'A', 'N'), ('D', 'A', 'A'), ('N', 'D', 'D'), ('N', 'D', 'N'), ('N', 'D', 'A'), ('N', 'N', 'D'), ('N', 'N', 'N'), ('N', 'N', 'A'), ('N', 'A', 'D'), ('N', 'A', 'N'), ('N', 'A', 'A'), ('A', 'D', 'D'), ('A', 'D', 'N'), ('A', 'D', 'A'), ('A', 'N', 'D'), ('A', 'N', 'N'), ('A', 'N', 'A'), ('A', 'A', 'D'), ('A', 'A', 'N'), ('A', 'A', 'A')]
# 39
# ('D',)
# ('N',)
# ('A',)
# ('D', 'D')
# ('D', 'N')
# ('D', 'A')
# ('N', 'D')
# ('N', 'N')
# ('N', 'A')
# ('A', 'D')
# ('A', 'N')
# ('A', 'A')
# ('D',)
# ('N',)
# ('A',)
# ('D', 'D')
# ('D', 'N')
# ('D', 'A')
# ('N', 'D')
# ('N', 'N')
# ('N', 'A')
# ('A', 'D')
# ('A', 'N')
# ('A', 'A')
# ('D',)
# ('N',)
# ('A',)
# ('D', 'D')
# ('D', 'N')
# ('D', 'A')
# ('N', 'D')
# ...

# %%
from itertools import product
from itertools import permutations

file = open('files/lexv_example.txt','rU')
raw_file = file.readlines()
raw_file = raw_file[0].split(' ')

order_sep = []
order = str('')
for i in raw_file:
    order += str(i).split('\n')[0]
    order_sep.append(str(i).split('\n')[0])
print order

comb = []
for i in order_sep:
    comb.append(i)
    
print 'comb',comb

lenght = 3
strings = ''

for n in range(2,lenght+1):
    prod = list(product(order,repeat=n))
    print prod
    
    for i in prod:
        for f in i:
            strings += f
        comb.append(strings)
        strings = ''
    
print 'comb',comb

final = []

for o in order:
    for i in comb:
        for r in i:
            if
# Out:
# DNA
# comb ['D', 'N', 'A']
# [('D', 'D'), ('D', 'N'), ('D', 'A'), ('N', 'D'), ('N', 'N'), ('N', 'A'), ('A', 'D'), ('A', 'N'), ('A', 'A')]
# [('D', 'D', 'D'), ('D', 'D', 'N'), ('D', 'D', 'A'), ('D', 'N', 'D'), ('D', 'N', 'N'), ('D', 'N', 'A'), ('D', 'A', 'D'), ('D', 'A', 'N'), ('D', 'A', 'A'), ('N', 'D', 'D'), ('N', 'D', 'N'), ('N', 'D', 'A'), ('N', 'N', 'D'), ('N', 'N', 'N'), ('N', 'N', 'A'), ('N', 'A', 'D'), ('N', 'A', 'N'), ('N', 'A', 'A'), ('A', 'D', 'D'), ('A', 'D', 'N'), ('A', 'D', 'A'), ('A', 'N', 'D'), ('A', 'N', 'N'), ('A', 'N', 'A'), ('A', 'A', 'D'), ('A', 'A', 'N'), ('A', 'A', 'A')]
# comb ['D', 'N', 'A', 'DD', 'DN', 'DA', 'ND', 'NN', 'NA', 'AD', 'AN', 'AA', 'DDD', 'DDN', 'DDA', 'DND', 'DNN', 'DNA', 'DAD', 'DAN', 'DAA', 'NDD', 'NDN', 'NDA', 'NND', 'NNN', 'NNA', 'NAD', 'NAN', 'NAA', 'ADD', 'ADN', 'ADA', 'AND', 'ANN', 'ANA', 'AAD', 'AAN', 'AAA']
# D
# N
# A
# DD
# DN
# DA
# ND
# NN
# NA
# AD
# AN
# AA
# DDD
# DDN
# DDA
# DND
# DNN
# DNA
# DAD
# DAN
# DAA
# NDD
# NDN
# NDA
# ...

# %%
sorted(comb, key=order)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-150-bff6f5ca75cc> in <module>()
# ----> 1 sorted(comb, key=order)
#
# TypeError: 'str' object is not callable

# %%
a = ('A','B','C')
sorted(a,key=('A','B','D','C'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-155-18f3583c780f> in <module>()
#       1 a = ('A','B','C')
# ----> 2 sorted(a,key=('A','B','D','C'))
#
# TypeError: 'tuple' object is not callable
